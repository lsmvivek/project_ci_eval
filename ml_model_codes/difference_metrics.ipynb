# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
save_plot = True
target_ = 'SoilMoist_S_tavg'     #   Tveg_tavg  Qs_tavg  SoilMoist_S_tavg
dir_ = '82.875_27.625'  # Ganga basin
# dir_ = '148.125_-29.125'      # Murray basin
# Out:
# '82.875_27.625'

# %%
# pcc_mcc_df = pd.read_csv('data/temporary/PCC-MC-results_{target_}_{dir_}.txt', index_col=None)
pcc_df = pd.read_csv(f'data/temporary/PCC-MC-results_{target_}_{dir_}.txt', index_col=None)
pcc_df_train = pd.read_csv(f'data/temporary/PCC-MC-results_{target_}_{dir_}_training.txt', index_col=None)
pcc_df, pcc_df_train
# Out:
# (    method  noise_level  r2_score      rmse       mae       nse   nse_mod  \
#  0      PCC          0.0  0.972060  0.188959  0.144421  0.959286  0.820770
#  1      PCC          0.0  0.985746  0.144522  0.115985  0.976183  0.856059
#  2      PCC          0.0  0.981877  0.141417  0.107850  0.977196  0.866156
#  3      PCC          0.0  0.985253  0.145755  0.115554  0.975775  0.856594
#  4      PCC          0.0  0.985134  0.119146  0.094205  0.983813  0.883089
#  ..     ...          ...       ...       ...       ...       ...       ...
#  245    PCC          1.0  0.337980  1.153503  0.927085  0.217150  0.109533
#  246    PCC          1.0  0.334373  1.167379  0.932411  0.187596  0.111753
#  247    PCC          1.0  0.322878  1.188707  0.959443  0.262914  0.134372
#  248    PCC          1.0  0.383430  1.098789  0.878459  0.302367  0.165001
#  249    PCC          1.0  0.283836  1.201737  0.959555  0.172410  0.105939
#
#            kge
#  0    0.958641
#  1    0.975524
#  2    0.980768
#  3    0.976207
#  4    0.988540
#  ..        ...
#  245  0.564231
#  246  0.543445
#  247  0.497563
#  248  0.580238
#  249  0.495333
#
#  [250 rows x 8 columns],
#      method  noise_level  r2_score      rmse       mae       nse   nse_mod  \
#  0      PCC          0.0  0.992897  0.129585  0.097689  0.989863  0.912333
#  1      PCC          0.0  0.995983  0.106733  0.084844  0.993123  0.923860
#  2      PCC          0.0  0.995818  0.107094  0.080485  0.993077  0.927771
#  3      PCC          0.0  0.996528  0.131100  0.102145  0.989625  0.908334
#  4      PCC          0.0  0.995388  0.100432  0.073329  0.993911  0.934194
#  ..     ...          ...       ...       ...       ...       ...       ...
#  245    PCC          1.0  0.803383  0.839336  0.649067  0.787952  0.563742
#  246    PCC          1.0  0.766976  0.912965  0.723174  0.754547  0.520086
#  247    PCC          1.0  0.765649  0.928322  0.726723  0.749730  0.520082
#  248    PCC          1.0  0.764379  0.915339  0.722467  0.756790  0.522421
#  249    PCC          1.0  0.775911  0.873079  0.698357  0.756287  0.510300
#
#            kge
#  0    0.943216
#  1    0.945438
#  2    0.949797
#  3    0.920401
#  4    0.966312
#  ..        ...
#  245  0.749627
#  246  0.735662
#  247  0.720093
#  248  0.752895
#  249  0.714767
#
#  [250 rows x 8 columns])

# %%
# tcdf_df = pd.read_csv('data/temporary/TCDF-MC-results_{target_}_{dir_}.txt', index_col=None)
tcdf_df = pd.read_csv(f'data/temporary/TCDF-MC-results_{target_}_{dir_}.txt', index_col=None)
tcdf_df_train = pd.read_csv(f'data/temporary/TCDF-MC-results_{target_}_{dir_}_training.txt', index_col=None)
tcdf_df, tcdf_df_train
# Out:
# (    method  noise_level  r2_score      rmse       mae       nse   nse_mod  \
#  0     TCDF          0.0  0.988056  0.121137  0.098259  0.983267  0.878058
#  1     TCDF          0.0  0.987770  0.112354  0.082551  0.985606  0.897552
#  2     TCDF          0.0  0.989525  0.106023  0.085085  0.987182  0.894408
#  3     TCDF          0.0  0.990698  0.166429  0.141899  0.968416  0.823900
#  4     TCDF          0.0  0.989665  0.125292  0.104129  0.982100  0.870773
#  ..     ...          ...       ...       ...       ...       ...       ...
#  245   TCDF          1.0  0.338731  1.116210  0.884771  0.333369  0.190641
#  246   TCDF          1.0  0.363246  1.092668  0.863593  0.363110  0.217718
#  247   TCDF          1.0  0.317163  1.094098  0.870838  0.309379  0.178405
#  248   TCDF          1.0  0.368677  1.060517  0.845672  0.365325  0.214756
#  249   TCDF          1.0  0.365840  1.063363  0.858877  0.341384  0.198789
#
#            kge
#  0    0.929557
#  1    0.953615
#  2    0.961863
#  3    0.927666
#  4    0.955367
#  ..        ...
#  245  0.454774
#  246  0.438568
#  247  0.371236
#  248  0.482341
#  249  0.451865
#
#  [250 rows x 8 columns],
#      method  noise_level  r2_score      rmse       mae       nse   nse_mod  \
#  0     TCDF          0.0  0.995768  0.133408  0.102776  0.989256  0.907767
#  1     TCDF          0.0  0.994684  0.104160  0.072779  0.993451  0.934687
#  2     TCDF          0.0  0.996124  0.109893  0.085498  0.992710  0.923273
#  3     TCDF          0.0  0.996167  0.146704  0.116779  0.987008  0.895201
#  4     TCDF          0.0  0.995306  0.113311  0.085886  0.992249  0.922925
#  ..     ...          ...       ...       ...       ...       ...       ...
#  245   TCDF          1.0  0.479155  1.281919  1.027306  0.477239  0.287219
#  246   TCDF          1.0  0.492623  1.303590  1.037114  0.490728  0.299704
#  247   TCDF          1.0  0.446793  1.352323  1.088455  0.438921  0.257322
#  248   TCDF          1.0  0.489273  1.309153  1.051629  0.482386  0.288768
#  249   TCDF          1.0  0.474324  1.317956  1.040977  0.471238  0.293178
#
#            kge
#  0    0.919119
#  1    0.963501
#  2    0.939596
#  3    0.913936
#  4    0.944117
#  ..        ...
#  245  0.534986
#  246  0.546827
#  247  0.468842
#  248  0.520174
#  249  0.521137
#
#  [250 rows x 8 columns])

# %%
# varlingam_df = pd.read_csv('data/temporary/VARLiNGAM-MC-results_{target_}_{dir_}.txt', index_col=None)
varlingam_df = pd.read_csv(f'data/temporary/VARLiNGAM-MC-results_{target_}_{dir_}.txt', index_col=None)
varlingam_df_train = pd.read_csv(f'data/temporary/VARLiNGAM-MC-results_{target_}_{dir_}_training.txt', index_col=None)
varlingam_df, varlingam_df_train
# Out:
# (        method  noise_level  r2_score      rmse       mae       nse   nse_mod  \
#  0    VARLiNGAM          0.0  0.989818  0.173278  0.146964  0.965763  0.817614
#  1    VARLiNGAM          0.0  0.990470  0.135169  0.113228  0.979166  0.859481
#  2    VARLiNGAM          0.0  0.984729  0.143737  0.122665  0.976441  0.847769
#  3    VARLiNGAM          0.0  0.989561  0.115549  0.094970  0.984775  0.882139
#  4    VARLiNGAM          0.0  0.988672  0.134547  0.111110  0.979357  0.862110
#  ..         ...          ...       ...       ...       ...       ...       ...
#  245  VARLiNGAM          1.0  0.383095  1.055664  0.845338  0.359436  0.208900
#  246  VARLiNGAM          1.0  0.384928  1.008328  0.810030  0.384591  0.219694
#  247  VARLiNGAM          1.0  0.401137  1.015460  0.824219  0.399714  0.219312
#  248  VARLiNGAM          1.0  0.351444  1.118880  0.888564  0.301427  0.181836
#  249  VARLiNGAM          1.0  0.342500  1.077941  0.869639  0.334413  0.195538
#
#            kge
#  0    0.911075
#  1    0.897017
#  2    0.927710
#  3    0.959504
#  4    0.941039
#  ..        ...
#  245  0.440751
#  246  0.471766
#  247  0.454875
#  248  0.381991
#  249  0.447131
#
#  [250 rows x 8 columns],
#          method  noise_level  r2_score      rmse       mae       nse   nse_mod  \
#  0    VARLiNGAM          0.0  0.997040  0.144042  0.118736  0.987475  0.893444
#  1    VARLiNGAM          0.0  0.996777  0.141822  0.112747  0.987858  0.898819
#  2    VARLiNGAM          0.0  0.995863  0.114585  0.090201  0.992074  0.919052
#  3    VARLiNGAM          0.0  0.996219  0.096642  0.072173  0.994362  0.935231
#  4    VARLiNGAM          0.0  0.996586  0.106958  0.084313  0.993094  0.924336
#  ..         ...          ...       ...       ...       ...       ...       ...
#  245  VARLiNGAM          1.0  0.547606  1.242295  1.004336  0.534957  0.329484
#  246  VARLiNGAM          1.0  0.565669  1.195209  0.940597  0.557729  0.348175
#  247  VARLiNGAM          1.0  0.554024  1.187991  0.947543  0.547088  0.330140
#  248  VARLiNGAM          1.0  0.564106  1.174086  0.932595  0.556725  0.339239
#  249  VARLiNGAM          1.0  0.605910  1.144502  0.908773  0.588182  0.373654
#
#            kge
#  0    0.907951
#  1    0.903966
#  2    0.946092
#  3    0.958189
#  4    0.941981
#  ..        ...
#  245  0.546707
#  246  0.588796
#  247  0.583031
#  248  0.586022
#  249  0.582974
#
#  [250 rows x 8 columns])

# %%
# pcmciplus_df = pd.read_csv('data/temporary/PCMCIplus-MC-results_{target_}_{dir_}.txt', index_col=None)
pcmciplus_df = pd.read_csv(f'data/temporary/PCMCIplus-MC-results_{target_}_{dir_}.txt', index_col=None)
pcmciplus_df_train = pd.read_csv(f'data/temporary/PCMCIplus-MC-results_{target_}_{dir_}_training.txt', index_col=None)
pcmciplus_df, pcmciplus_df_train
# Out:
# (        method  noise_level  r2_score      rmse       mae       nse   nse_mod  \
#  0    PCMCIplus          0.0  0.992533  0.123840  0.101521  0.982512  0.874010
#  1    PCMCIplus          0.0  0.989982  0.163441  0.139000  0.969540  0.827498
#  2    PCMCIplus          0.0  0.991737  0.167893  0.141437  0.967857  0.824473
#  3    PCMCIplus          0.0  0.992413  0.098613  0.076963  0.988911  0.904486
#  4    PCMCIplus          0.0  0.992881  0.108964  0.090758  0.986461  0.887366
#  ..         ...          ...       ...       ...       ...       ...       ...
#  245  PCMCIplus          1.0  0.371454  1.084122  0.868837  0.352637  0.207803
#  246  PCMCIplus          1.0  0.410016  1.091892  0.873701  0.389768  0.223836
#  247  PCMCIplus          1.0  0.390480  1.035042  0.830379  0.386686  0.211140
#  248  PCMCIplus          1.0  0.370024  1.094023  0.883933  0.354286  0.211190
#  249  PCMCIplus          1.0  0.301798  1.110459  0.883662  0.281159  0.172671
#
#            kge
#  0    0.943823
#  1    0.924902
#  2    0.900564
#  3    0.963620
#  4    0.959207
#  ..        ...
#  245  0.421373
#  246  0.470698
#  247  0.477703
#  248  0.426287
#  249  0.392973
#
#  [250 rows x 8 columns],
#          method  noise_level  r2_score      rmse       mae       nse   nse_mod  \
#  0    PCMCIplus          0.0  0.997075  0.106768  0.084863  0.993119  0.923842
#  1    PCMCIplus          0.0  0.996728  0.139693  0.115478  0.988220  0.896369
#  2    PCMCIplus          0.0  0.995698  0.152183  0.120895  0.986019  0.891507
#  3    PCMCIplus          0.0  0.996815  0.113531  0.089656  0.992219  0.919542
#  4    PCMCIplus          0.0  0.997573  0.103666  0.084825  0.993513  0.923877
#  ..         ...          ...       ...       ...       ...       ...       ...
#  245  PCMCIplus          1.0  0.489286  1.264978  0.991614  0.479269  0.297751
#  246  PCMCIplus          1.0  0.486327  1.315952  1.045555  0.480712  0.296258
#  247  PCMCIplus          1.0  0.497404  1.307716  1.032610  0.492657  0.299338
#  248  PCMCIplus          1.0  0.477548  1.329552  1.066150  0.467515  0.273569
#  249  PCMCIplus          1.0  0.509687  1.285360  1.020518  0.504993  0.313848
#
#            kge
#  0    0.939841
#  1    0.910511
#  2    0.916457
#  3    0.930641
#  4    0.937555
#  ..        ...
#  245  0.499337
#  246  0.523680
#  247  0.531940
#  248  0.494135
#  249  0.545153
#
#  [250 rows x 8 columns])

# %%
# dynotears_df = pd.read_csv('data/temporary/DYNOTEARS-MC-results_{target_}_{dir_}.txt', index_col=None)
dynotears_df = pd.read_csv(f'data/temporary/DYNOTEARS-MC-results_{target_}_{dir_}.txt', index_col=None)
dynotears_df_train = pd.read_csv(f'data/temporary/DYNOTEARS-MC-results_{target_}_{dir_}_training.txt', index_col=None)
dynotears_df, dynotears_df_train
# Out:
# (        method  noise_level  r2_score      rmse       mae       nse   nse_mod  \
#  0    DYNOTEARS          0.0  0.989239  0.111532  0.089658  0.985815  0.888732
#  1    DYNOTEARS          0.0  0.988649  0.155616  0.132512  0.972386  0.835549
#  2    DYNOTEARS          0.0  0.989005  0.135443  0.113026  0.979082  0.859732
#  3    DYNOTEARS          0.0  0.988123  0.131013  0.102887  0.980428  0.872314
#  4    DYNOTEARS          0.0  0.990317  0.128765  0.107276  0.981093  0.866868
#  ..         ...          ...       ...       ...       ...       ...       ...
#  245  DYNOTEARS          1.0  0.323182  1.173851  0.941362  0.241043  0.141676
#  246  DYNOTEARS          1.0  0.381241  1.099883  0.887825  0.380803  0.211289
#  247  DYNOTEARS          1.0  0.364344  1.060265  0.847488  0.356430  0.194887
#  248  DYNOTEARS          1.0  0.402455  1.060306  0.847184  0.393473  0.243985
#  249  DYNOTEARS          1.0  0.310467  1.108925  0.895475  0.283144  0.161611
#
#            kge
#  0    0.936139
#  1    0.905649
#  2    0.925610
#  3    0.923283
#  4    0.925849
#  ..        ...
#  245  0.411748
#  246  0.444104
#  247  0.426092
#  248  0.476431
#  249  0.412512
#
#  [250 rows x 8 columns],
#          method  noise_level  r2_score      rmse       mae       nse   nse_mod  \
#  0    DYNOTEARS          0.0  0.997186  0.108235  0.083802  0.992928  0.924795
#  1    DYNOTEARS          0.0  0.995838  0.151385  0.120960  0.986166  0.891449
#  2    DYNOTEARS          0.0  0.996442  0.134732  0.108915  0.989042  0.902258
#  3    DYNOTEARS          0.0  0.996448  0.124942  0.097599  0.990577  0.912413
#  4    DYNOTEARS          0.0  0.996523  0.140492  0.109291  0.988085  0.901920
#  ..         ...          ...       ...       ...       ...       ...       ...
#  245  DYNOTEARS          1.0  0.509228  1.241663  0.987474  0.498287  0.300683
#  246  DYNOTEARS          1.0  0.483034  1.316775  1.045383  0.480063  0.296373
#  247  DYNOTEARS          1.0  0.494615  1.312732  1.040786  0.488757  0.293790
#  248  DYNOTEARS          1.0  0.496398  1.299646  1.033309  0.491200  0.295945
#  249  DYNOTEARS          1.0  0.529219  1.261706  1.004162  0.523045  0.324845
#
#            kge
#  0    0.939922
#  1    0.899969
#  2    0.912245
#  3    0.922392
#  4    0.907377
#  ..        ...
#  245  0.528091
#  246  0.533448
#  247  0.526210
#  248  0.529920
#  249  0.556299
#
#  [250 rows x 8 columns])

# %%
# # Reorder the dataframe based on the methods
# # TCDF, PCMCIplus, DYNOTEARS, VARLiNGAM, PCC
# method_order = ['TCDF', 'PCMCIplus', 'DYNOTEARS', 'VARLiNGAM', 'PCC']
# monte_carlo_df['method'] = pd.Categorical(monte_carlo_df['method'], categories=method_order, ordered=True)

# %%
monte_carlo_df = pd.concat([pcc_df, tcdf_df, varlingam_df, pcmciplus_df, dynotears_df], ignore_index=True)
monte_carlo_df_train = pd.concat([pcc_df_train, tcdf_df_train, varlingam_df_train, pcmciplus_df_train, dynotears_df_train], ignore_index=True)

monte_carlo_df, monte_carlo_df_train
# Out:
# (         method  noise_level  r2_score      rmse       mae       nse  \
#  0           PCC          0.0  0.972060  0.188959  0.144421  0.959286
#  1           PCC          0.0  0.985746  0.144522  0.115985  0.976183
#  2           PCC          0.0  0.981877  0.141417  0.107850  0.977196
#  3           PCC          0.0  0.985253  0.145755  0.115554  0.975775
#  4           PCC          0.0  0.985134  0.119146  0.094205  0.983813
#  ...         ...          ...       ...       ...       ...       ...
#  1245  DYNOTEARS          1.0  0.323182  1.173851  0.941362  0.241043
#  1246  DYNOTEARS          1.0  0.381241  1.099883  0.887825  0.380803
#  1247  DYNOTEARS          1.0  0.364344  1.060265  0.847488  0.356430
#  1248  DYNOTEARS          1.0  0.402455  1.060306  0.847184  0.393473
#  1249  DYNOTEARS          1.0  0.310467  1.108925  0.895475  0.283144
#
#         nse_mod       kge
#  0     0.820770  0.958641
#  1     0.856059  0.975524
#  2     0.866156  0.980768
#  3     0.856594  0.976207
#  4     0.883089  0.988540
#  ...        ...       ...
#  1245  0.141676  0.411748
#  1246  0.211289  0.444104
#  1247  0.194887  0.426092
#  1248  0.243985  0.476431
#  1249  0.161611  0.412512
#
#  [1250 rows x 8 columns],
#           method  noise_level  r2_score      rmse       mae       nse  \
#  0           PCC          0.0  0.992897  0.129585  0.097689  0.989863
#  1           PCC          0.0  0.995983  0.106733  0.084844  0.993123
#  2           PCC          0.0  0.995818  0.107094  0.080485  0.993077
#  3           PCC          0.0  0.996528  0.131100  0.102145  0.989625
#  4           PCC          0.0  0.995388  0.100432  0.073329  0.993911
#  ...         ...          ...       ...       ...       ...       ...
#  1245  DYNOTEARS          1.0  0.509228  1.241663  0.987474  0.498287
#  1246  DYNOTEARS          1.0  0.483034  1.316775  1.045383  0.480063
#  1247  DYNOTEARS          1.0  0.494615  1.312732  1.040786  0.488757
#  1248  DYNOTEARS          1.0  0.496398  1.299646  1.033309  0.491200
#  1249  DYNOTEARS          1.0  0.529219  1.261706  1.004162  0.523045
#
#         nse_mod       kge
#  0     0.912333  0.943216
#  1     0.923860  0.945438
#  2     0.927771  0.949797
#  3     0.908334  0.920401
#  4     0.934194  0.966312
#  ...        ...       ...
#  1245  0.300683  0.528091
#  1246  0.296373  0.533448
#  1247  0.293790  0.526210
#  1248  0.295945  0.529920
#  1249  0.324845  0.556299
#
#  [1250 rows x 8 columns])

# %%
diff_df = pd.DataFrame(columns=monte_carlo_df.columns)
for m in ['r2_score', 'rmse', 'mae', 'nse', 'nse_mod', 'kge']:
    diff_df[m] = monte_carlo_df[m] - monte_carlo_df_train[m]
diff_df['method'] = monte_carlo_df['method']
diff_df['noise_level'] = monte_carlo_df['noise_level']

# %%
# base_palette = sns.color_palette("colorblind", 5)
# new_order = [1, 3, 4, 2, 0]  # 0-index mapping from your description
# custom_palette = [base_palette[i] for i in new_order]
# sns.palplot(custom_palette)
# plt.show()

# %%
diff_df
# Out:
#          method  noise_level  r2_score      rmse       mae       nse  \
# 0           PCC          0.0 -0.020837  0.059374  0.046732 -0.030578
# 1           PCC          0.0 -0.010237  0.037788  0.031141 -0.016940
# 2           PCC          0.0 -0.013941  0.034323  0.027364 -0.015881
# 3           PCC          0.0 -0.011274  0.014655  0.013410 -0.013850
# 4           PCC          0.0 -0.010254  0.018714  0.020876 -0.010098
# ...         ...          ...       ...       ...       ...       ...
# 1245  DYNOTEARS          1.0 -0.186046 -0.067812 -0.046113 -0.257243
# 1246  DYNOTEARS          1.0 -0.101793 -0.216892 -0.157558 -0.099260
# 1247  DYNOTEARS          1.0 -0.130270 -0.252468 -0.193299 -0.132327
# 1248  DYNOTEARS          1.0 -0.093943 -0.239340 -0.186125 -0.097727
# 1249  DYNOTEARS          1.0 -0.218752 -0.152780 -0.108687 -0.239901
#
#        nse_mod       kge
# 0    -0.091562  0.015424
# 1    -0.067800  0.030086
# 2    -0.061616  0.030971
# 3    -0.051740  0.055806
# 4    -0.051104  0.022229
# ...        ...       ...
# 1245 -0.159007 -0.116342
# 1246 -0.085085 -0.089344
# 1247 -0.098903 -0.100117
# 1248 -0.051960 -0.053489
# 1249 -0.163235 -0.143787
#
# [1250 rows x 8 columns]

# %%
# plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.family"] = "sans-serif"

sns.set_theme(context='notebook', style='white', font='sans-serif', font_scale=1,)
fig, ax = plt.subplots(1, 1, figsize=(5, 5), dpi=100)

sns.boxplot(
    data=diff_df, x='noise_level', y='r2_score', hue='method',
    orient='v', width=1, dodge=True, ax=ax, legend=False, fill=False,
    flierprops={'marker': 'o', 'markersize': 0.3},
    palette=sns.color_palette('colorblind', 5),
    # palette=custom_palette,
    whis=[5, 90], linewidth=1.,
    )
noise_levels = diff_df['noise_level'].unique()
for i, nl in enumerate(noise_levels):
    if i % 2 == 0:
        ax.axvspan(i - 0.5, i + 0.5, facecolor="lightgrey", alpha=0.2, zorder=0)
        ax.axvspan(i - 0.5, i + 0.5, facecolor="lightgrey", alpha=0.2, zorder=0)
ax.axhline(0, color='red', linestyle='--', linewidth=0.7, zorder=1)

# ax.set_ylim(0, 1.0)
ax.grid(True, linestyle="-", linewidth=0.5, color='grey', alpha=0.3, zorder=-1, axis='y')
ax.set_xlabel('Noise Level', fontsize=12)
ax.set_ylabel(r'$\Delta \mathrm{R^2}$', fontsize=12)
ax.yaxis.set_label_coords(-0.15, 0.5)
ax.tick_params(axis='y', labelsize=12)
ax.tick_params(length=5, axis='y', which='major', direction='out', bottom=True, left=True)
plt.yticks(fontsize=12)
ax.minorticks_on()
ax.tick_params(length=2, axis='y', which='minor', direction='out', bottom=True, left=True)
# Add a boundary around the scatterplot
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(0.5)
    spine.set_alpha(0.2)
plt.tight_layout()
if save_plot:
    plt.savefig(f'./figs/_delta_r2.svg', bbox_inches='tight', dpi=400, pad_inches=0.05)
plt.show()

# %%
plt.rcParams["font.family"] = "sans-serif"

sns.set_theme(context='notebook', style='white', font='sans-serif', font_scale=1,)
fig, ax = plt.subplots(1, 1, figsize=(5, 5), dpi=100)

sns.boxplot(
    data=diff_df, x='noise_level', y='nse', hue='method',
    orient='v', width=1, dodge=True, ax=ax, legend=False, fill=False,
    flierprops={'marker': 'o', 'markersize': 0.3},
    palette=sns.color_palette('colorblind', 5),
    # palette=custom_palette,
    whis=[5, 90], linewidth=1.,
    )
noise_levels = diff_df['noise_level'].unique()
for i, nl in enumerate(noise_levels):
    if i % 2 == 0:
        ax.axvspan(i - 0.5, i + 0.5, facecolor="lightgrey", alpha=0.2, zorder=0)
        ax.axvspan(i - 0.5, i + 0.5, facecolor="lightgrey", alpha=0.2, zorder=0)

# Add a red line at y=0
ax.axhline(0, color='red', linestyle='--', linewidth=0.7, zorder=1)

# ax.set_ylim(-1.0, 1.0)
# ax.set_yticks(np.arange(-1.0, 1.01, step=0.25))

ax.grid(True, linestyle="-", linewidth=0.5, color='grey', alpha=0.3, zorder=-1, axis='y')
ax.set_xlabel('Noise Level', fontsize=12)
ax.set_ylabel(r'$\Delta \mathrm{NSE}$', fontsize=12)
ax.yaxis.set_label_coords(-0.1, 0.5)

ax.tick_params(axis='y', labelsize=12)
ax.tick_params(length=5, axis='y', which='major', direction='out', bottom=True, left=True)
plt.yticks(fontsize=12)
ax.minorticks_on()
ax.tick_params(length=2, axis='y', which='minor', direction='out', bottom=True, left=True)
# Add a boundary around the scatterplot
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(0.5)
    spine.set_alpha(0.2)
plt.tight_layout()
if save_plot:
    plt.savefig(f'./figs/_delta_nse.svg', bbox_inches='tight', dpi=400, pad_inches=0.05)
plt.show()

# %%
plt.rcParams["font.family"] = "sans-serif"

sns.set_theme(context='notebook', style='white', font='sans-serif', font_scale=1,)
fig, ax = plt.subplots(1, 1, figsize=(5, 5), dpi=100)

sns.boxplot(
    data=diff_df, x='noise_level', y='nse_mod', hue='method',
    orient='v', width=1, dodge=True, ax=ax, legend=False, fill=False,
    flierprops={'marker': 'o', 'markersize': 0.3},
    palette=sns.color_palette('colorblind', 5), 
    # palette=custom_palette,
    whis=[5, 90], linewidth=1.,
    )
noise_levels = diff_df['noise_level'].unique()
for i, nl in enumerate(noise_levels):
    if i % 2 == 0:
        ax.axvspan(i - 0.5, i + 0.5, facecolor="lightgrey", alpha=0.2, zorder=0)
        ax.axvspan(i - 0.5, i + 0.5, facecolor="lightgrey", alpha=0.2, zorder=0)

# Add a red line at y=0
ax.axhline(0, color='red', linestyle='--', linewidth=0.7, zorder=0)

# ax.set_ylim(-1.0, 1.0)
# ax.set_yticks(np.arange(-1.0, 1.01, step=0.25))
ax.yaxis.set_label_coords(-0.15, 0.5)

ax.grid(True, linestyle="-", linewidth=0.5, color='grey', alpha=0.3, zorder=-1, axis='y')
ax.set_xlabel('Noise Level', fontsize=12)
ax.set_ylabel(r'$\Delta \mathrm{NSE_{mod}}$', fontsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.tick_params(length=5, axis='y', which='major', direction='out', bottom=True, left=True)
plt.yticks(fontsize=12)
ax.minorticks_on()
ax.tick_params(length=2, axis='y', which='minor', direction='out', bottom=True, left=True)
# Add a boundary around the scatterplot
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(0.5)
    spine.set_alpha(0.2)
plt.tight_layout()
if save_plot:
    plt.savefig(f'./figs/_delta_nse_modified.svg', bbox_inches='tight', dpi=400, pad_inches=0.05)
plt.show()

# %%
plt.rcParams["font.family"] = "sans-serif"

sns.set_theme(context='notebook', style='white', font='sans-serif', font_scale=1,)
fig, ax = plt.subplots(1, 1, figsize=(5, 5), dpi=100)

sns.boxplot(
    data=diff_df, x='noise_level', y='kge', hue='method',
    orient='v', width=1, dodge=True, ax=ax, legend=False, fill=False,
    flierprops={'marker': 'o', 'markersize': 0.3},
    palette=sns.color_palette('colorblind', 5),
    # palette=custom_palette,
    whis=[5, 90], linewidth=1.,
    )
noise_levels = diff_df['noise_level'].unique()
for i, nl in enumerate(noise_levels):
    if i % 2 == 0:
        ax.axvspan(i - 0.5, i + 0.5, facecolor="lightgrey", alpha=0.2, zorder=0)
        ax.axvspan(i - 0.5, i + 0.5, facecolor="lightgrey", alpha=0.2, zorder=0)

# Add a red line at y=0
ax.axhline(0, color='red', linestyle='--', linewidth=0.7, zorder=0)

# ax.set_ylim(-0.5, 1.0)
# ax.set_yticks(np.arange(-0.5, 1.01, step=0.25))
ax.yaxis.set_label_coords(-0.15, 0.5)


ax.grid(True, linestyle="-", linewidth=0.5, color='grey', alpha=0.3, zorder=-1, axis='y')
ax.set_xlabel('Noise Level', fontsize=12)
ax.set_ylabel(r'$\Delta \mathrm{KGE}$', fontsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.tick_params(length=5, axis='y', which='major', direction='out', bottom=True, left=True)
plt.yticks(fontsize=12)
ax.minorticks_on()
ax.tick_params(length=2, axis='y', which='minor', direction='out', bottom=True, left=True)
# Add a boundary around the scatterplot
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(0.5)
    spine.set_alpha(0.2)
plt.tight_layout()
if save_plot:
    plt.savefig(f'./figs/_delta_kge.svg', bbox_inches='tight', dpi=400, pad_inches=0.05)
plt.show()

# %%
plt.rcParams["font.family"] = "sans-serif"

sns.set_theme(context='notebook', style='white', font='sans-serif', font_scale=1,)
fig, ax = plt.subplots(1, 1, figsize=(5, 5), dpi=100)

sns.boxplot(
    data=diff_df, x='noise_level', y='rmse', hue='method',
    orient='v', width=1, dodge=True, ax=ax, legend=False, fill=False,
    flierprops={'marker': 'o', 'markersize': 0.3},
    palette=sns.color_palette('colorblind', 5),
    # palette=custom_palette,
    whis=[5, 90], linewidth=1.,
    )
noise_levels = diff_df['noise_level'].unique()
for i, nl in enumerate(noise_levels):
    if i % 2 == 0:
        ax.axvspan(i - 0.5, i + 0.5, facecolor="lightgrey", alpha=0.2, zorder=0)
        ax.axvspan(i - 0.5, i + 0.5, facecolor="lightgrey", alpha=0.2, zorder=0)
ax.axhline(0, color='red', linestyle='--', linewidth=0.7, zorder=0)
# ax.set_ylim(0, 3*1e-5)

ax.grid(True, linestyle="-", linewidth=0.5, color='grey', alpha=0.3, zorder=-1, axis='y')
ax.set_xlabel('Noise Level', fontsize=12)
ax.set_ylabel(r'$\Delta \mathrm{RMSE}$', fontsize=12)
ax.yaxis.set_label_coords(-0.15, 0.5)
ax.tick_params(axis='y', labelsize=12)
ax.tick_params(length=5, axis='y', which='major', direction='out', bottom=True, left=True)
plt.yticks(fontsize=12)
ax.minorticks_on()
ax.tick_params(length=2, axis='y', which='minor', direction='out', bottom=True, left=True)
# Add a boundary around the scatterplot
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(0.5)
    spine.set_alpha(0.2)
plt.tight_layout()
if save_plot:
    plt.savefig(f'./figs/_delta_rmse.svg', bbox_inches='tight', dpi=400, pad_inches=0.05)
plt.show()

# %%
plt.rcParams["font.family"] = "sans-serif"

sns.set_theme(context='notebook', style='white', font='sans-serif', font_scale=1,)
fig, ax = plt.subplots(1, 1, figsize=(5, 5), dpi=100)

sns.boxplot(
    data=diff_df, x='noise_level', y='mae', hue='method',
    orient='v', width=1, dodge=True, ax=ax, legend=False, fill=False,
    flierprops={'marker': 'o', 'markersize': 0.3},
    palette=sns.color_palette('colorblind', 5), 
    # palette=custom_palette,
    whis=[5, 90], linewidth=1.,
    )
noise_levels = diff_df['noise_level'].unique()
for i, nl in enumerate(noise_levels):
    if i % 2 == 0:
        ax.axvspan(i - 0.5, i + 0.5, facecolor="lightgrey", alpha=0.2, zorder=0)
        ax.axvspan(i - 0.5, i + 0.5, facecolor="lightgrey", alpha=0.2, zorder=0)
ax.axhline(0, color='red', linestyle='--', linewidth=0.7, zorder=0)

# ax.set_ylim(0, 3*1e-5)

ax.grid(True, linestyle="-", linewidth=0.5, color='grey', alpha=0.3, zorder=-1, axis='y')
ax.set_xlabel('Noise Level', fontsize=12)
ax.set_ylabel(r'$\Delta \mathrm{MAE}$', fontsize=12)
ax.yaxis.set_label_coords(-0.15, 0.5)
ax.tick_params(axis='y', labelsize=12)
ax.tick_params(length=5, axis='y', which='major', direction='out', bottom=True, left=True)
plt.yticks(fontsize=12)
ax.minorticks_on()
ax.tick_params(length=2, axis='y', which='minor', direction='out', bottom=True, left=True)
# Add a boundary around the scatterplot
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(0.5)
    spine.set_alpha(0.2)
plt.tight_layout()
if save_plot:
    plt.savefig(f'./figs/_delta_mae.svg', bbox_inches='tight', dpi=400, pad_inches=0.05)
plt.show()
